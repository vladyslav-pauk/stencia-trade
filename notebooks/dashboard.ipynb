# %%
from src.utils.data import fetch_stock_data, process_data
from src.utils.chart import create_chart, add_indicator_charts
from src.utils.indicators import add_indicator_data
from src.trend.support_resistance import add_support_resistance_data


ticker = "AAPL"
period = "1wk"
indicators = ['S&R'] # 'SMA', 'EMA', 'TDA'

data = fetch_stock_data(ticker, period)
data = process_data(data)
# data = add_indicator_data(data)
# data = add_support_resistance_data(data)

fig = create_chart(data, ticker, period, "Candlestick")
# fig = add_indicator_charts(fig, data, indicators)
fig.show()
# Out:
# <div>                            <div id="c9ace8ad-dcef-4914-b3b7-d20b63f2b1b4" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c9ace8ad-dcef-4914-b3b7-d20b63f2b1b4")) {                    Plotly.newPlot(                        "c9ace8ad-dcef-4914-b3b7-d20b63f2b1b4",                        [{"close":[229.83999633789062,229.16000366210938,230.4949951171875,229.86619567871094,229.36000061035156,229.0399932861328,229.2899932861328,229.36000061035156,229.0500030517578,229.22000122070312,228.5019989013672,228.470703125,228.69000244140625,228.6649932861328,228.47999572753906,228.47000122070312,228.44000244140625,228.55929565429688,228.625,228.6999053955078,228.39019775390625,228.0399932861328,227.83999633789062,227.69000244140625,227.48199462890625,227.63
# ...

# %%
# fixme: range breaks

# UI
# todo: interface for periods/dates, intervals
# todo: interface for indicator settings (https://docs.streamlit.io/develop/tutorials/multipage/st.page_link-nav),
#  change setup for strategies depending on chosen
# todo: trading panel - trading strategy settings, backtest button

# Chores
# todo: write README
# todo: clean src.utils (move src.data to utils?)

# Features
# todo: support/resistance weekly vs daily
# todo: implement trends and tune support resistance
# todo: implement trading panel - show actions on chart with individual profit losses, show profits curve
# todo: implement screener (add a new tab to app https://docs.streamlit.io/develop/api-reference/layout/st.tabs)
# todo: fix and tune tda
# todo: additional ta indicators, volume, important news
# todo: watchlist, save/delete to/from watchlist button, when clicked drop down watchlist


# Notebooks
# todo: clean and fix notebooks
